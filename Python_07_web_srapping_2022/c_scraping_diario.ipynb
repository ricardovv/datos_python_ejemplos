# %% [markdown]
# ## Captura de datos:
#
# # C– Web Scraping Sitio Noticias
#
# ### Prof. Ricardo Vega M. - Escuela de Diseño Universidad Católica de Chile - 2022
#
# Scraping es una serie de técnicas para obtener datos desde un archivo de la web. Por ejemplo: Título, Autor, Fecha, Contenidos de texto, ruta de imagen, etc. Para esto se va a una URL (dirección web) y se explora su estructura HTML, tomando los elementos que se necesiten.
#
# En el siguiente ejemplo revisaremos la obtención de titulos y la url (Uniform Resource Locator) de artículos de una web.
#
# Ver más en: https://issuu.com/ricardov_net/docs/datos_obtencion_scraping_2022

# %%
## Importar las librerías a usar:
import pandas as pd # libreria para trabajar con estructuras de datos

import requests # para conectarse a las url
from bs4 import BeautifulSoup # para hacer scraping desde sitios web

# %% [markdown]
# ## A - Realizar request
#
# request (solicitud) a la página, usando un objeto BeautifulSoup para capturar elementos de la página HTML.

# %%
## Primero preguntar por respuesta desde el servidor que aloja la página. 
req1 = requests.get('https://www.elmostrador.cl/cultura/agenda/page/2/')
larespuesta = req1.status_code 

## mostrar respuesta, ojo se puede demorar un poco
## respuesta 200, indica que la solicitud fue éxitosa.
larespuesta
# Out:
# 200

# %%
## entrega HTML  
soup1 = BeautifulSoup(req1.text, "lxml")

## mostrar elhtml
#soup1

# %% [markdown]
# ## B - Seleccionar contenido: find()
#
# Funciones para buscar el contenido del los tags de interés.

# %%
## Seleccionaremos la etiquta article

## find( ) – Funcion entrega el primer elemento hijo que encuentre, segun los parámetros. 
mi_art = soup1.find("article")

mi_art
# Out:
# <article class="row">
# <figure class="col-xs-5 col-sm-2 col-md-2">
# <img alt="Lanzamiento del libro " chileno="" piano="" pipochi="" popular="" src="https://media.elmostrador.cl/2022/08/Oscar_2-210x210.jpg" title="Lanzamiento del libro «Pipochi, piano popular chileno»"/>
# </figure> <!-- /imagen noticia -->
# <div class="col-xs-7 col-sm-10 col-md-10">
# <p><span class="heading-portadas heading-cultura">CULTURA</span></p>
# <h4><a href="https://www.elmostrador.cl/cultura/2022/08/28/lanzamiento-del-libro-pipochi-piano-popular-chileno/" title="Ir a enlace">Lanzamiento del libro "Pipochi, piano popular chileno"</a></h4>
# <small><em>por</em> <strong>El Mostrador Cultura</strong></small>
# </div>
# </article>

# %%
## Seleccionaremos texto de la etiqueta
#mi_art_text = soup1.find("article").text
#mi_art_text

## Seleccionaremos imagen
mi_art_img = soup1.find("article").img

mi_art_img
# Out:
# <img alt="Lanzamiento del libro " chileno="" piano="" pipochi="" popular="" src="https://media.elmostrador.cl/2022/08/Oscar_2-210x210.jpg" title="Lanzamiento del libro «Pipochi, piano popular chileno»"/>

# %%
## Seleccionar lo neceario 

# mi_art_text_solo = soup1.find("article").a.text
# mi_art_text_solo

## Seleccionaremos imagen
mi_art_img_url = soup1.find("article").img['src']

mi_art_img_url
# Out:
# 'https://media.elmostrador.cl/2022/08/Oscar_2-210x210.jpg'

# %% [markdown]
# ## C – Seleccionar contenido: findAll( )
#
# Entrega todos los elementos que encuentre de un tipo.

# %%
## find_all seleciona todos los elementos de un tipo, en este caso article
mis_arts = soup1.find_all("article")

print( mis_arts )
# Out:
# [<article class="row">
# <figure class="col-xs-5 col-sm-2 col-md-2">
# <img alt="Lanzamiento del libro " chileno="" piano="" pipochi="" popular="" src="https://media.elmostrador.cl/2022/08/Oscar_2-210x210.jpg" title="Lanzamiento del libro «Pipochi, piano popular chileno»"/>
# </figure> <!-- /imagen noticia -->
# <div class="col-xs-7 col-sm-10 col-md-10">
# <p><span class="heading-portadas heading-cultura">CULTURA</span></p>
# <h4><a href="https://www.elmostrador.cl/cultura/2022/08/28/lanzamiento-del-libro-pipochi-piano-popular-chileno/" title="Ir a enlace">Lanzamiento del libro "Pipochi, piano popular chileno"</a></h4>
# <small><em>por</em> <strong>El Mostrador Cultura</strong></small>
# </div>
# </article>, <article class="row">
# <figure class="col-xs-5 col-sm-2 col-md-2">
# <img alt="“La gran noche del canto popular” en La Pintana" src="https://media.elmostrador.cl/2022/08/pintana-portada-210x210.png" title="“La gran noche del canto popular” en La Pintana"/>
# </figure> <!-- /imagen noticia -->
# <div class="col-xs-7 col-sm-10 col-md-10">
# <p><span class="heading-portadas heading-cultura">CULTURA</span></p>
# <h4><a href="https://www.elmostrador.cl/cultura/2022/08/27/la-gran-noche-del-canto-popular-en-la-pintana/" title="Ir a enlace">“La gran noche del canto popular” en La Pintana</a></h4>
# <small><em>por</em> <strong>El Mostrador Cultura</strong></small>
# </div>
# </article>, <article class="row">
# <figure class="col-xs-5 col-sm-2 col-md-2">
# <img alt="Cantata Mapudungún en Teatro Municipal de Maipú" src="https://media.elmostrador.cl/2022/08/unnamed-98-210x210.png" title="Cantata Mapudungún en Teatro Municipal de Maipú"/>
# </figure> <!-- /imagen noticia -->
# <div class="col-xs-7 col-sm-10 col-md-10">
# <p><span class="heading-portadas heading-cultura">CULTURA</span></p>
# <h4><a href="https://www.elmostrador.cl/cultura/2022/08/26/cantata-mapudungun-en-teatro-municipal-de-maipu/" title="Ir a enlace">Cantata Mapudungún en Teatro Municipal de Maipú</a></h4>
# <small><em>por</em> <strong>El Mostrador Cultura</strong></small>
# </div>
# </article>, <article class="row">
# <figure class="col-xs-5 col-sm-2 col-md-2">
# <img alt="Presentación de libro “El coleccionista” de Matías Prado" src="https://media.elmostrador.cl/2022/08/MG1_8023-210x210.jpg" title="Presentación de libro “El coleccionista” de Matías Prado"/>
# </figure> <!-- /imagen noticia -->
# <div class="col-xs-7 col-sm-10 col-md-10">
# <p><span class="heading-portadas heading-cultura">CULTURA</span></p>
# <h4><a href="https://www.elmostrador.cl/cultura/2022/08/26/presentacion-de-libro-el-coleccionista-de-matias-prado/" title="Ir a enlace">Presentación de libro “El coleccionista” de Matías Prado</a></h4>
# <small><em>por</em> <strong>El Mostrador Cultura</strong></small>
# </div>
# </article>, <article class="row">
# <figure class="col-xs-5 col-sm-2 col-md-2">
# <img alt="Agrupación de cueca “Los 30 pesos” en Valparaíso" src="https://media.elmostrador.cl/2022/08/unnamed-100-210x210.png" title="Agrupación de cueca “Los 30 pesos” en Valparaíso"/>
# </figure> <!-- /imagen noticia -->
# <div class="col-xs-7 col-sm-10 col-md-10">
# <p><span class="heading-portadas heading-cultura">CULTURA</span></p>
# <h4><a href="https://www.elmostrador.cl/cultura/2022/08/26/agrupacion-de-cueca-los-30-pesos-en-valparaiso/" title="Ir a enlace">Agrupación de cueca “Los 30 pesos” en Valparaíso</a></h4>
# <small><em>por</em> <strong>El Mostrador Cultura</strong></small>
# </div>
# </article>, <article class="row">
# <figure class="col-xs-5 col-sm-2 col-md-2">
# <img alt="Jornada cultural " constitucionales="" en="" lecturas="" movimiento="" src="https://media.elmostrador.cl/2022/08/Biblioteca-Nacional-210x210.jpg" title="Jornada cultural «Lecturas Constitucionales en Movimiento»"/>
# </figure> <!-- /imagen noticia -->
# <div class="col-xs-7 col-sm-10 col-md-10">
# <p><span class="heading-portadas heading-cultura">CULTURA</span></p>
# <h4><a href="https://www.elmostrador.cl/cultura/2022/08/25/jornada-cultural-lecturas-constitucionales-en-movimiento/" title="Ir a enlace">Jornada cultural "Lecturas Constitucionales en Movimiento"</a></h4>
# <small><em>por</em> <strong>El Mostrador Cultura</strong></small>
# </div>
# </article>, <article class="row">
# <figure class="col-xs-5 col-sm-2 col-md-2">
# <img alt="Winter Rock Fest en Faq Records" src="https://media.elmostrador.cl/2022/08/WhatsApp-Image-2022-08-24-at-9.36.28-AM-210x210.jpeg" title="Winter Rock Fest en Faq Records"/>
# </figure> <!-- /imagen noticia -->
# <div class="col-xs-7 col-sm-10 col-md-10">
# <p><span class="heading-portadas heading-cultura">CULTURA</span></p>
# <h4><a href="https://www.elmostrador.cl/cultura/2022/08/25/winter-rock-fest-en-faq-records/" title="Ir a enlace">Winter Rock Fest en Faq Records</a></h4>
# <small><em>por</em> <strong>El Mostrador Cultura</strong></small>
# </div>
# </article>, <article class="row">
# <figure class="col-xs-5 col-sm-2 col-md-2">
# <img alt="Lanzamiento de libro " de="" ib="" j.="" la="" langlois="" m.="" mar="" src="https://media.elmostrador.cl/2022/08/Jose-Miguel-Ibanez-Langlois-210x210.jpg" title="Lanzamiento de libro «La Virgen María» de J. M. Ibáñez Langlois" virgen=""/>
# </figure> <!-- /imagen noticia -->
# <div class="col-xs-7 col-sm-10 col-md-10">
# <p><span class="heading-portadas heading-cultura">CULTURA</span></p>
# <h4><a href="https://www.elmostrador.cl/cultura/2022/08/25/lanzamiento-de-libro-la-virgen-maria-de-j-m-ibanez-langlois/" title="Ir a enlace">Lanzamiento de libro "La Virgen María" de J. M. Ibáñez Langlois</a></h4>
# <small><em>por</em> <strong>El Mostrador Cultura</strong></small>
# </div>
# </article>, <article class="row">
# <figure class="col-xs-5 col-sm-2 col-md-2">
# <img alt="" cisnes="" de="" el="" en="" lago="" los="" municipal="" santiago="" src="https://media.elmostrador.cl/2022/08/ballet-210x210.png" teatro="" title="«El lago de los cisnes» en Teatro Municipal de Santiago"/>
# </figure> <!-- /imagen noticia -->
# <div class="col-xs-7 col-sm-10 col-md-10">
# <p><span class="heading-portadas heading-cultura">CULTURA</span></p>
# <h4><a href="https://www.elmostrador.cl/cultura/2022/08/24/el-lago-de-los-cisnes-en-teatro-municipal-de-santiago/" title="Ir a enlace">"El lago de los cisnes" en Teatro Municipal de Santiago</a></h4>
# <small><em>por</em> <strong>El Mostrador Cultura</strong></small>
# </div>
# </article>, <article class="row">
# <figure class="col-xs-5 col-sm-2 col-md-2">
# <img alt="Intervención lumínica en Chiu Chiu" src="https://media.elmostrador.cl/2022/08/Intervención-lumínica-de-Julio-Escobar-210x210.jpg" title="Intervención lumínica en Chiu Chiu"/>
# </figure> <!-- /imagen noticia -->
# <div class="col-xs-7 col-sm-10 col-md-10">
# <p><span class="heading-portadas heading-cultura">CULTURA</span></p>
# <h4><a href="https://www.elmostrador.cl/cultura/2022/08/24/intervencion-luminica-en-chiu-chiu/" title="Ir a enlace">Intervención lumínica en Chiu Chiu</a></h4>
# <small><em>por</em> <strong>El Mostrador Cultura</strong></small>
# </div>
# </article>, <article class="col-xs-12 col-sm-12 col-md-12">
# <div class="col-xs-12 col-sm-12 col-md-12">
# <figure class="col-md-3 col-sm-3 col-xs-3">
# <a href="https://www.elmostrador.cl/dia/2022/08/31/ministra-vallejo-en-cierre-de-campana-chile-vota-informado-entregamos-mas-de-un-millon-de-ejemplares-de-la-propuesta-de-nueva-constitucion/" title="Ir a enlace">
# <i class="icon-iso-multimedia chico" style="display:none;">
# <span class="path1"></span>
# <span class="path2"></span>
# <span class="path3"></span>
# </i>
# <img alt="Ministra Vallejo en cierre de campaña Chile Vota Informado: «Entregamos más de un millón de ejemplares de la propuesta de nueva Constitución»" class="col-xs-12 col-sm-12 col-md-12" src="https://media.elmostrador.cl/2022/08/Vallejo-Chile-Vota-Informado-210x210.jpg" title="Ministra Vallejo en cierre de campaña Chile Vota Informado: «Entregamos más de un millón de ejemplares de la propuesta de nueva Constitución»"/>
# </a>
# </figure>
# <div class="col-md-9 col-sm-9 col-xs-9">
# <h3><a href="https://www.elmostrador.cl/dia/2022/08/31/ministra-vallejo-en-cierre-de-campana-chile-vota-informado-entregamos-mas-de-un-millon-de-ejemplares-de-la-propuesta-de-nueva-constitucion/" title="Ir a enlace">Ministra Vallejo en cierre de campaña Chile Vota Informado: «Entregamos más de un millón de ejemplares de la propuesta de nueva Constitución»</a></h3>
# </div>
# </div>
# </article>, <article class="col-xs-12 col-sm-12 col-md-12">
# <div class="col-xs-12 col-sm-12 col-md-12">
# <figure class="col-md-3 col-sm-3 col-xs-3">
# <a href="https://www.elmostrador.cl/noticias/pais/2022/08/31/la-esperada-participacion-de-michelle-bachelet-en-la-franja-del-apruebo-cuando-las-mujeres-hacemos-cosas-la-historia-avanza/" title="Ir a enlace">
# <i class="icon-iso-multimedia chico" style="display:none;">
# <span class="path1"></span>
# <span class="path2"></span>
# <span class="path3"></span>
# </i>
# <img alt="La esperada participación de Michelle Bachelet en la franja del Apruebo: «Cuando las mujeres hacemos cosas, la historia avanza»" class="col-xs-12 col-sm-12 col-md-12" src="https://media.elmostrador.cl/2022/08/Michelle-Bachelet-en-la-franja-del-Apruebo-210x210.png" title="La esperada participación de Michelle Bachelet en la franja del Apruebo: «Cuando las mujeres hacemos cosas, la historia avanza»"/>
# </a>
# </figure>
# <div class="col-md-9 col-sm-9 col-xs-9">
# <h3><a href="https://www.elmostrador.cl/noticias/pais/2022/08/31/la-esperada-participacion-de-michelle-bachelet-en-la-franja-del-apruebo-cuando-las-mujeres-hacemos-cosas-la-historia-avanza/" title="Ir a enlace">La esperada participación de Michelle Bachelet en la franja del Apruebo: «Cuando las mujeres hacemos cosas, la historia avanza»</a></h3>
# </div>
# </div>
# </article>, <article class="col-xs-12 col-sm-12 col-md-12">
# <div class="col-xs-12 col-sm-12 col-md-12">
# <figure class="col-md-3 col-sm-3 col-xs-3">
# <a href="https://www.elmostrador.cl/noticias/pais/2022/09/01/modelos-de-prediccion-matematicos-contradicen-encuestas-y-dan-por-ganadora-a-la-opcion-apruebo/" title="Ir a enlace">
# <img alt="Modelos de predicción matemáticos contradicen encuestas y dan por ganadora a la opción Apruebo" class="col-xs-12 col-sm-12 col-md-12" src="https://media.elmostrador.cl/2022/08/e85db55b459292812ee8178dea-210x210.jpg" style="height:auto;" title="Modelos de predicción matemáticos contradicen encuestas y dan por ganadora a la opción Apruebo"/>
# </a>
# </figure>
# <div class="col-md-9 col-sm-9 col-xs-9">
# <h3><a href="https://www.elmostrador.cl/noticias/pais/2022/09/01/modelos-de-prediccion-matematicos-contradicen-encuestas-y-dan-por-ganadora-a-la-opcion-apruebo/" title="Ir a enlace">Modelos de predicción matemáticos contradicen encuestas y dan por ganadora a la opción Apruebo</a></h3>
# </div>
# </div>
# </article>, <article class="col-xs-12 col-sm-12 col-md-12">
# <div class="col-xs-12 col-sm-12 col-md-12">
# <figure class="col-md-3 col-sm-3 col-xs-3">
# <a href="https://www.elmostrador.cl/destacado/2022/09/01/cierres-de-campana-de-la-lucha-contra-la-dictadura-desde-el-apruebo-hasta-una-hoja-de-ruta-post-4s-desde-el-rechazo/" title="Ir a enlace">
# <img alt="Cierres de campaña en la RM se toman el centro de Santiago y lo alto del cerro San Cristóbal" class="col-xs-12 col-sm-12 col-md-12" src="https://media.elmostrador.cl/2022/08/Campillai-Frei-y-Salinas-210x210.png" style="height:auto;" title="Cierres de campaña en la RM se toman el centro de Santiago y lo alto del cerro San Cristóbal"/>
# </a>
# </figure>
# <div class="col-md-9 col-sm-9 col-xs-9">
# <h3><a href="https://www.elmostrador.cl/destacado/2022/09/01/cierres-de-campana-de-la-lucha-contra-la-dictadura-desde-el-apruebo-hasta-una-hoja-de-ruta-post-4s-desde-el-rechazo/" title="Ir a enlace">Cierres de campaña en la RM se toman el centro de Santiago y lo alto del cerro San Cristóbal</a></h3>
# </div>
# </div>
# </article>, <article class="col-xs-12 col-sm-12 col-md-12">
# <div class="row contenido-entrada">
# <figure class="col-xs-3 col-sm-3 col-md-3">
# <img alt="Plebiscito de salida: sin violencia a quien piensa distinto" class="img-circle" src="https://media.elmostrador.cl/users/10277d1a6af916bfeca3778473e4192c.jpg" title="Plebiscito de salida: sin violencia a quien piensa distinto"/>
# </figure>
# <div class="col-xs-9 col-sm-9 col-md-9">
# <h3><a href="https://www.elmostrador.cl/noticias/opinion/2022/09/01/plebiscito-de-salida-sin-violencia-a-quien-piensa-distinto/" title="Ir a enlace">Plebiscito de salida: sin violencia a quien piensa distinto</a></h3>
# <p>por <a href="https://www.elmostrador.cl/autor/camiloherrera/" rel="author">Camilo Herrera</a></p>
# </div>
# </div>
# </article>, <article class="col-xs-12 col-sm-12 col-md-12">
# <div class="row contenido-entrada">
# <figure class="col-xs-3 col-sm-3 col-md-3">
# <img alt="El renacer del turismo es ahora" class="img-circle" src="https://media.elmostrador.cl/users/e4d5ee0874d6b0a13a046d5174c7704c.jpg" title="El renacer del turismo es ahora"/>
# </figure>
# <div class="col-xs-9 col-sm-9 col-md-9">
# <h3><a href="https://www.elmostrador.cl/noticias/opinion/2022/09/01/el-renacer-del-turismo-es-ahora/" title="Ir a enlace">El renacer del turismo es ahora</a></h3>
# <p>por <a href="https://www.elmostrador.cl/autor/oscarsantelices/" rel="author">Óscar Santelices</a></p>
# </div>
# </div>
# </article>, <article class="col-xs-12 col-sm-12 col-md-12">
# <div class="row contenido-entrada">
# <figure class="col-xs-3 col-sm-3 col-md-3">
# <img alt="¡Avancemos hacia la transformación continua!" class="img-circle" src="https://media.elmostrador.cl/users/269f46bced0d6175f44a803391c07016_100x100.jpg" title="¡Avancemos hacia la transformación continua!"/>
# </figure>
# <div class="col-xs-9 col-sm-9 col-md-9">
# <h3><a href="https://www.elmostrador.cl/noticias/opinion/2022/09/01/avancemos-hacia-la-transformacion-continua/" title="Ir a enlace">¡Avancemos hacia la transformación continua!</a></h3>
# <p>por <a href="https://www.elmostrador.cl/autor/ruben-belluomo/" rel="author">Rubén Belluomo</a></p>
# </div>
# </div>
# </article>, <article class="col-xs-12 col-sm-12 col-md-12">
# <div class="col-xs-12 col-sm-12 col-md-12">
# <figure class="col-md-3 col-sm-3 col-xs-3">
# <a href="https://www.elmostrador.cl/mercados/2022/08/31/sonami-elige-a-jorge-riesco-como-nuevo-presidente-reemplaza-a-diego-hernandez-en-el-cargo/" title="Ir a enlace">
# <img alt="Sonami elige a Jorge Riesco como nuevo presidente: reemplaza a Diego Hernández en el cargo" class="col-xs-12 col-sm-12 col-md-12" src="https://media.elmostrador.cl/2022/08/Diseno-sin-titulo-2022-08-31T185631.625-210x210.png" style="height:auto;" title="Sonami elige a Jorge Riesco como nuevo presidente: reemplaza a Diego Hernández en el cargo"/>
# </a>
# </figure>
# <div class="col-md-9 col-sm-9 col-xs-9">
# <h3><a href="https://www.elmostrador.cl/mercados/2022/08/31/sonami-elige-a-jorge-riesco-como-nuevo-presidente-reemplaza-a-diego-hernandez-en-el-cargo/" title="Ir a enlace">Sonami elige a Jorge Riesco como nuevo presidente: reemplaza a Diego Hernández en el cargo</a></h3>
# </div>
# </div>
# </article>, <article class="col-xs-12 col-sm-12 col-md-12">
# <div class="col-xs-12 col-sm-12 col-md-12">
# <figure class="col-md-3 col-sm-3 col-xs-3">
# <a href="https://www.elmostrador.cl/mercados/2022/08/31/dolar-cierra-al-alza-en-la-ultima-jornada-de-agosto-a-la-espera-del-plebiscito-constitucional-y-posibles-alzas-de-tasas-en-ee-uu/" title="Ir a enlace">
# <img alt="Dólar cierra al alza en la última jornada de agosto, a la espera del plebiscito constitucional y posibles alzas de tasas en EE.UU." class="col-xs-12 col-sm-12 col-md-12" src="https://media.elmostrador.cl/2022/08/Diseno-sin-titulo-2022-08-31T175959.470-210x210.png" style="height:auto;" title="Dólar cierra al alza en la última jornada de agosto, a la espera del plebiscito constitucional y posibles alzas de tasas en EE.UU."/>
# </a>
# </figure>
# <div class="col-md-9 col-sm-9 col-xs-9">
# <h3><a href="https://www.elmostrador.cl/mercados/2022/08/31/dolar-cierra-al-alza-en-la-ultima-jornada-de-agosto-a-la-espera-del-plebiscito-constitucional-y-posibles-alzas-de-tasas-en-ee-uu/" title="Ir a enlace">Dólar cierra al alza en la última jornada de agosto, a la espera del plebiscito constitucional y posibles alzas de tasas en EE.UU.</a></h3>
# </div>
# </div>
# </article>, <article class="col-xs-12 col-sm-12 col-md-12">
# <div class="col-xs-12 col-sm-12 col-md-12">
# <figure class="col-md-3 col-sm-3 col-xs-3 btn-play-sidebar">
# <a href="https://www.elmostrador.cl/destacado/2022/08/31/lorenzo-gazmuri-y-lo-que-viene-tras-el-plebiscito-chile-necesita-un-pacto-politico-social-y-economico/" title="Ir a enlace">
# <img alt="Lorenzo Gazmuri y lo que viene tras el plebiscito: «Chile necesita un pacto político, social y económico»" class="col-xs-12 col-sm-12 col-md-12" src="https://media.elmostrador.cl/2022/08/Captura-de-Pantalla-2022-08-30-a-las-22.45.15-210x210.png" title="Lorenzo Gazmuri y lo que viene tras el plebiscito: «Chile necesita un pacto político, social y económico»"/>
# <i class="icon-iso-multimedia" style="display:none;">
# <span class="path1"></span>
# <span class="path2"></span>
# <span class="path3"></span>
# </i>
# </a>
# </figure>
# <div class="col-md-9 col-sm-9 col-xs-9">
# <h3><a href="https://www.elmostrador.cl/destacado/2022/08/31/lorenzo-gazmuri-y-lo-que-viene-tras-el-plebiscito-chile-necesita-un-pacto-politico-social-y-economico/" title="Ir a enlace">Lorenzo Gazmuri y lo que viene tras el plebiscito: «Chile necesita un pacto político, social y económico»</a></h3>
# </div>
# </div>
# </article>, <article class="col-xs-12 col-sm-12 col-md-12">
# <div class="col-xs-12 col-sm-12 col-md-12">
# <figure class="col-md-3 col-sm-3 col-xs-3 btn-play-sidebar">
# <a href="https://www.elmostrador.cl/destacado/2022/08/30/directora-juridica-de-oceana-chile-si-seguimos-actuando-como-hoy-en-dia-se-espera-que-en-20-anos-tripliquemos-la-cantidad-de-plastico-que-llegue-a-los-oceanos/" title="Ir a enlace">
# <img alt="Directora jurídica de Oceana Chile: «Si seguimos actuando como hoy en día, se espera que en 20 años tripliquemos la cantidad de plástico que llegue a los océanos»" class="col-xs-12 col-sm-12 col-md-12" src="https://media.elmostrador.cl/2022/08/Oceana-Chile-plasticos-210x210.jpg" title="Directora jurídica de Oceana Chile: «Si seguimos actuando como hoy en día, se espera que en 20 años tripliquemos la cantidad de plástico que llegue a los océanos»"/>
# <i class="icon-iso-multimedia" style="display:none;">
# <span class="path1"></span>
# <span class="path2"></span>
# <span class="path3"></span>
# </i>
# </a>
# </figure>
# <div class="col-md-9 col-sm-9 col-xs-9">
# <h3><a href="https://www.elmostrador.cl/destacado/2022/08/30/directora-juridica-de-oceana-chile-si-seguimos-actuando-como-hoy-en-dia-se-espera-que-en-20-anos-tripliquemos-la-cantidad-de-plastico-que-llegue-a-los-oceanos/" title="Ir a enlace">Directora jurídica de Oceana Chile: «Si seguimos actuando como hoy en día, se espera que en 20 años tripliquemos la cantidad de plástico que llegue a los océanos»</a></h3>
# </div>
# </div>
# </article>, <article class="col-xs-12 col-sm-12 col-md-12">
# <div class="col-xs-12 col-sm-12 col-md-12">
# <figure class="col-md-3 col-sm-3 col-xs-3">
# <a href="https://www.elmostrador.cl/cultura/2022/09/01/carlos-cabezas-y-el-debut-de-electrodomesticos-en-el-festival-victor-jara-tributar-a-su-memoria-es-una-oportunidad-de-agradecimiento/" title="Ir a enlace">
# <img alt="Carlos Cabezas y el debut de Electrodomésticos en el festival Víctor Jara: “Tributar a su memoria es una oportunidad de agradecimiento”" class="col-xs-12 col-sm-12 col-md-12" src="https://media.elmostrador.cl/2022/08/Carlos-Cabezas-900x600-1-210x210.jpeg" style="height:auto;" title="Carlos Cabezas y el debut de Electrodomésticos en el festival Víctor Jara: “Tributar a su memoria es una oportunidad de agradecimiento”"/>
# </a>
# </figure>
# <div class="col-md-9 col-sm-9 col-xs-9">
# <h3><a href="https://www.elmostrador.cl/cultura/2022/09/01/carlos-cabezas-y-el-debut-de-electrodomesticos-en-el-festival-victor-jara-tributar-a-su-memoria-es-una-oportunidad-de-agradecimiento/" title="Ir a enlace">Carlos Cabezas y el debut de Electrodomésticos en el festival Víctor Jara: “Tributar a su memoria es una oportunidad de agradecimiento”</a></h3>
# </div>
# </div>
# </article>, <article class="col-xs-12 col-sm-12 col-md-12">
# <div class="col-xs-12 col-sm-12 col-md-12">
# <figure class="col-md-3 col-sm-3 col-xs-3">
# <a href="https://www.elmostrador.cl/cultura/2022/09/01/ministra-de-medio-ambiente-recibe-declaracion-oficial-de-jovenes-chilenos-sobre-cambio-climatico/" title="Ir a enlace">
# <img alt="Ministra de Medio Ambiente recibe declaración oficial de jóvenes chilenos sobre cambio climático" class="col-xs-12 col-sm-12 col-md-12" src="https://media.elmostrador.cl/2022/08/LCOY-Ministra-Medioambiente-210x210.jpg" style="height:auto;" title="Ministra de Medio Ambiente recibe declaración oficial de jóvenes chilenos sobre cambio climático"/>
# </a>
# </figure>
# <div class="col-md-9 col-sm-9 col-xs-9">
# <h3><a href="https://www.elmostrador.cl/cultura/2022/09/01/ministra-de-medio-ambiente-recibe-declaracion-oficial-de-jovenes-chilenos-sobre-cambio-climatico/" title="Ir a enlace">Ministra de Medio Ambiente recibe declaración oficial de jóvenes chilenos sobre cambio climático</a></h3>
# </div>
# </div>
# </article>, <article class="col-xs-12 col-sm-12 col-md-12">
# <div class="col-xs-12 col-sm-12 col-md-12">
# <figure class="col-md-3 col-sm-3 col-xs-3">
# <a href="https://www.elmostrador.cl/noticias/deportes/2022/08/31/fifa-cita-a-declarar-a-futbolista-byron-castillo-tras-apelacion-de-chile-por-caso-de-falsa-nacionalidad/" title="Ir a enlace">
# <img alt="FIFA cita a declarar a futbolista Byron Castillo tras apelación de Chile por caso de falsa nacionalidad" class="col-xs-12 col-sm-12 col-md-12" src="https://media.elmostrador.cl/2022/08/Diseno-sin-titulo-2022-08-31T222936.541-210x210.png" style="height:auto;" title="FIFA cita a declarar a futbolista Byron Castillo tras apelación de Chile por caso de falsa nacionalidad"/>
# </a>
# </figure>
# <div class="col-md-9 col-sm-9 col-xs-9">
# <h3><a href="https://www.elmostrador.cl/noticias/deportes/2022/08/31/fifa-cita-a-declarar-a-futbolista-byron-castillo-tras-apelacion-de-chile-por-caso-de-falsa-nacionalidad/" title="Ir a enlace">FIFA cita a declarar a futbolista Byron Castillo tras apelación de Chile por caso de falsa nacionalidad</a></h3>
# </div>
# </div>
# </article>, <article class="col-xs-12 col-sm-12 col-md-12">
# <div class="col-xs-12 col-sm-12 col-md-12">
# <figure class="col-md-3 col-sm-3 col-xs-3">
# <a href="https://www.elmostrador.cl/noticias/deportes/2022/08/31/cristian-garin-cae-ante-alex-de-minaur-y-se-despide-del-us-open/" title="Ir a enlace">
# <img alt="Cristian Garin cae ante Alex De Minaur y se despide del US Open" class="col-xs-12 col-sm-12 col-md-12" src="https://media.elmostrador.cl/2022/08/A_UNO_1160860-1-210x210.jpg" style="height:auto;" title="Cristian Garin cae ante Alex De Minaur y se despide del US Open"/>
# </a>
# </figure>
# <div class="col-md-9 col-sm-9 col-xs-9">
# <h3><a href="https://www.elmostrador.cl/noticias/deportes/2022/08/31/cristian-garin-cae-ante-alex-de-minaur-y-se-despide-del-us-open/" title="Ir a enlace">Cristian Garin cae ante Alex De Minaur y se despide del US Open</a></h3>
# </div>
# </div>
# </article>]

# %%
print( "Primer arts –", mis_arts[0] )
# Out:
# Primer arts – <article class="row">
# <figure class="col-xs-5 col-sm-2 col-md-2">
# <img alt="Lanzamiento del libro " chileno="" piano="" pipochi="" popular="" src="https://media.elmostrador.cl/2022/08/Oscar_2-210x210.jpg" title="Lanzamiento del libro «Pipochi, piano popular chileno»"/>
# </figure> <!-- /imagen noticia -->
# <div class="col-xs-7 col-sm-10 col-md-10">
# <p><span class="heading-portadas heading-cultura">CULTURA</span></p>
# <h4><a href="https://www.elmostrador.cl/cultura/2022/08/28/lanzamiento-del-libro-pipochi-piano-popular-chileno/" title="Ir a enlace">Lanzamiento del libro "Pipochi, piano popular chileno"</a></h4>
# <small><em>por</em> <strong>El Mostrador Cultura</strong></small>
# </div>
# </article>

# %%
## Mostrar otros elementos de la seleccion 
#print( "Cuantos arts –", len(mis_arts) )
#print( "Primer arts –", mis_arts[0] )
#print( "Primer url imagen en arts –", mis_arts[0].img['src'] )
print( "Primer tit en arts –", mis_arts[0].a.get_text() )
# Out:
# Primer tit en arts – Lanzamiento del libro "Pipochi, piano popular chileno"

# %% [markdown]
# ## D - Obtener todos los de un tipo y guardarlos en una lista cada uno

# %%
# Crear listas de los url de imagenes y los titulos de los articulos

los_titulos = []
las_img_url = []


## Recorreremos los articulos
for i in range( len(mis_arts) ):
    ## variables para cada elemento
    cadatitulo = mis_arts[ i ].a.get_text()
    cadalink   = mis_arts[ i ].img['src'] 

    ## append a cada lista
    los_titulos.append(cadatitulo)
    las_img_url.append(cadalink)

    
## mostrar
#las_img_url
los_titulos
# Out:
# ['Lanzamiento del libro "Pipochi, piano popular chileno"',
#  '“La gran noche del canto popular” en La Pintana',
#  'Cantata Mapudungún en Teatro Municipal de Maipú',
#  'Presentación de libro “El coleccionista” de Matías Prado',
#  'Agrupación de cueca “Los 30 pesos” en Valparaíso',
#  'Jornada cultural "Lecturas Constitucionales en Movimiento"',
#  'Winter Rock Fest en Faq Records',
#  'Lanzamiento de libro "La Virgen María" de J. M. Ibáñez Langlois',
#  '"El lago de los cisnes" en Teatro Municipal de Santiago',
#  'Intervención lumínica en Chiu Chiu',
#  '\n\n\n\n\n\n\n',
#  '\n\n\n\n\n\n\n',
#  '\n\n',
#  '\n\n',
#  'Plebiscito de salida: sin violencia a quien piensa distinto',
#  'El renacer del turismo es ahora',
#  '¡Avancemos hacia la transformación continua!',
#  '\n\n',
#  '\n\n',
#  '\n\n\n\n\n\n\n',
#  '\n\n\n\n\n\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n']

# %%
## Lo pasamos a un df paraluego guardarlo como CSV
df_diario = pd.DataFrame( {'elemento_titulo':los_titulos,'img_url':las_img_url} )

df_diario
# Out:
#                                       elemento_titulo  \
# 0   Lanzamiento del libro "Pipochi, piano popular ...
# 1     “La gran noche del canto popular” en La Pintana
# 2     Cantata Mapudungún en Teatro Municipal de Maipú
# 3   Presentación de libro “El coleccionista” de Ma...
# 4    Agrupación de cueca “Los 30 pesos” en Valparaíso
# 5   Jornada cultural "Lecturas Constitucionales en...
# 6                     Winter Rock Fest en Faq Records
# 7   Lanzamiento de libro "La Virgen María" de J. M...
# 8   "El lago de los cisnes" en Teatro Municipal de...
# 9                  Intervención lumínica en Chiu Chiu
# 10                                     \n\n\n\n\n\n\n
# 11                                     \n\n\n\n\n\n\n
# 12                                               \n\n
# 13                                               \n\n
# 14  Plebiscito de salida: sin violencia a quien pi...
# 15                    El renacer del turismo es ahora
# 16       ¡Avancemos hacia la transformación continua!
# 17                                               \n\n
# 18                                               \n\n
# 19                                     \n\n\n\n\n\n\n
# 20                                     \n\n\n\n\n\n\n
# 21                                               \n\n
# 22                                               \n\n
# 23                                               \n\n
# 24                                               \n\n
#
#                                               img_url
# 0   https://media.elmostrador.cl/2022/08/Oscar_2-2...
# 1   https://media.elmostrador.cl/2022/08/pintana-p...
# 2   https://media.elmostrador.cl/2022/08/unnamed-9...
# 3   https://media.elmostrador.cl/2022/08/MG1_8023-...
# 4   https://media.elmostrador.cl/2022/08/unnamed-1...
# 5   https://media.elmostrador.cl/2022/08/Bibliotec...
# 6   https://media.elmostrador.cl/2022/08/WhatsApp-...
# 7   https://media.elmostrador.cl/2022/08/Jose-Migu...
# 8   https://media.elmostrador.cl/2022/08/ballet-21...
# 9   https://media.elmostrador.cl/2022/08/Intervenc...
# 10  https://media.elmostrador.cl/2022/08/Vallejo-C...
# 11  https://media.elmostrador.cl/2022/08/Michelle-...
# 12  https://media.elmostrador.cl/2022/08/e85db55b4...
# 13  https://media.elmostrador.cl/2022/08/Campillai...
# 14  https://media.elmostrador.cl/users/10277d1a6af...
# 15  https://media.elmostrador.cl/users/e4d5ee0874d...
# 16  https://media.elmostrador.cl/users/269f46bced0...
# 17  https://media.elmostrador.cl/2022/08/Diseno-si...
# 18  https://media.elmostrador.cl/2022/08/Diseno-si...
# 19  https://media.elmostrador.cl/2022/08/Captura-d...
# 20  https://media.elmostrador.cl/2022/08/Oceana-Ch...
# 21  https://media.elmostrador.cl/2022/08/Carlos-Ca...
# 22  https://media.elmostrador.cl/2022/08/LCOY-Mini...
# 23  https://media.elmostrador.cl/2022/08/Diseno-si...
# 24  https://media.elmostrador.cl/2022/08/A_UNO_116...

# %%
## Botar las lineas que no nos interesen
df_diario = df_diario.drop(df_diario.index[10:])
df_diario
# Out:
#                                      elemento_titulo  \
# 0  Lanzamiento del libro "Pipochi, piano popular ...
# 1    “La gran noche del canto popular” en La Pintana
# 2    Cantata Mapudungún en Teatro Municipal de Maipú
# 3  Presentación de libro “El coleccionista” de Ma...
# 4   Agrupación de cueca “Los 30 pesos” en Valparaíso
# 5  Jornada cultural "Lecturas Constitucionales en...
# 6                    Winter Rock Fest en Faq Records
# 7  Lanzamiento de libro "La Virgen María" de J. M...
# 8  "El lago de los cisnes" en Teatro Municipal de...
# 9                 Intervención lumínica en Chiu Chiu
#
#                                              img_url
# 0  https://media.elmostrador.cl/2022/08/Oscar_2-2...
# 1  https://media.elmostrador.cl/2022/08/pintana-p...
# 2  https://media.elmostrador.cl/2022/08/unnamed-9...
# 3  https://media.elmostrador.cl/2022/08/MG1_8023-...
# 4  https://media.elmostrador.cl/2022/08/unnamed-1...
# 5  https://media.elmostrador.cl/2022/08/Bibliotec...
# 6  https://media.elmostrador.cl/2022/08/WhatsApp-...
# 7  https://media.elmostrador.cl/2022/08/Jose-Migu...
# 8  https://media.elmostrador.cl/2022/08/ballet-21...
# 9  https://media.elmostrador.cl/2022/08/Intervenc...

# %%
### Guardar en archivo

## Ojo, el archivo se llama datos_diario.csv y se guarda en la carpeta txt_diario 
## Si no existe dicha carpeta debe crearla

df_diario.to_csv('txt_diario/datos_diario.csv')

# %% [markdown]
# ## PUEDE PROBAR CON LO SIGUIENTE:
# * Ver otras páginas de noticias y obtener su información.
# * Para esto debe reconocer la estrcutrura HTML de dicha página, e indentificar los elemento y etiquetas HTML de interés.
